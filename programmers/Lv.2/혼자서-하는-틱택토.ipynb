# %%
FIRST_PLAYER = "O"
SECOND_PLAYER = "X"
BOARD_SIZE = 3

def check_win(board, player):

    for i in range(len(board)):
        if (
            all(board[i][j] == player for j in range(BOARD_SIZE)) 
            or all(board[j][i] == player for j in range(BOARD_SIZE))
        ): return True
    
    if (
        all ([board[i][i] == player for i in range(BOARD_SIZE)]) 
        or all ([board[i][BOARD_SIZE-1-i] == player for i in range(BOARD_SIZE)])
    ): return True
    
    return False

def solution(board):
    
    first_marker_counter = ''.join(board).count(FIRST_PLAYER)
    second_marker_counter = ''.join(board).count(SECOND_PLAYER)
    
    if not (
        first_marker_counter == second_marker_counter 
        or first_marker_counter == second_marker_counter + 1
    ):return 0

    is_first_win = check_win(board, FIRST_PLAYER)
    is_second_win = check_win(board, SECOND_PLAYER)
    
    # 선공이 이겼는데
    if is_first_win and (  
        is_second_win  # 후공도 이길수는 없다
        or first_marker_counter == second_marker_counter  # 후공의 말이 선공과 같을 수는 없다
        or not first_marker_counter == second_marker_counter + 1  # 후공의 말이 선공의 말보다 하나 초과하여, 작을 수 없다.
    ): return 0


    if is_second_win and not (first_marker_counter == second_marker_counter):  
        return 0
    
    return 1

# %%
FIRST_PLAYER = "O"
SECOND_PLAYER = "X"
BOARD_SIZE = 3

def check_win(board, player):

    for i in range(len(board)):
        if (
            all(board[i][j] == player for j in range(BOARD_SIZE)) 
            or all(board[j][i] == player for j in range(BOARD_SIZE))
        ): return True
    
    if (
        all ([board[i][i] == player for i in range(BOARD_SIZE)]) 
        or all ([board[i][BOARD_SIZE-1-i] == player for i in range(BOARD_SIZE)])
    ): return True
    
    return False

def solution(board):
    
    first_marker_counter = ''.join(board).count(FIRST_PLAYER)
    second_marker_counter = ''.join(board).count(SECOND_PLAYER)

    is_marker_right = True
    if not (
        first_marker_counter == second_marker_counter 
        or first_marker_counter == second_marker_counter + 1
    ): is_marker_right = False

    is_first_win = check_win(board, FIRST_PLAYER)
    is_second_win = check_win(board, SECOND_PLAYER)
    
    # 선공이 이겼는데
    if is_first_win and (  
        is_second_win  # 후공도 이길수는 없다
        or not is_marker_right
    ): return 0


    if is_second_win and not (first_marker_counter == second_marker_counter):  
        return 0
    
    if not is_marker_right:
        return 0
    
    return 1
